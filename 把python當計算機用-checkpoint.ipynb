# %%
1+1
# Out:
# 2

# %%
2+3*81
# Out:
# 245

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(30)
# Out:
# -0.9880316240928618

# %%
plot([-2,10,3,7,-7])

# %%
randn(10)
# Out:
# array([ 0.28392661,  1.92506173,  0.43577134, -0.36840046,  0.07480365,
#         0.14403345, -0.45594529,  0.52636433,  0.38164985, -0.32731958])

# %%
plot(randn(100))

# %%
plot([-2,1,4,7],[3,-5,6,0])
